# %% [markdown]
# # Building a regression model for predicting house sale prices

# %%
import pickle
import pathlib

import numpy as np
import pandas as pd

# %%
DATA_DIR = pathlib.Path.cwd() / 'data'
print(DATA_DIR)
# Out:
# /Users/enriccogemha/Developer/HousePriceRegressor/data

# %%
clean_data_path = DATA_DIR / 'processed' / 'ames_clean.pkl'

# %%
with open(clean_data_path, 'rb') as file:
    data = pickle.load(file)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2877 entries, 0 to 2929
# Data columns (total 70 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS.SubClass      2877 non-null   category
#  1   MS.Zoning        2877 non-null   category
#  2   Lot.Frontage     2877 non-null   float64
#  3   Lot.Area         2877 non-null   float64
#  4   Lot.Shape        2877 non-null   category
#  5   Land.Contour     2877 non-null   category
#  6   Lot.Config       2877 non-null   category
#  7   Land.Slope       2877 non-null   category
#  8   Neighborhood     2877 non-null   category
#  9   Bldg.Type        2877 non-null   category
#  10  House.Style      2877 non-null   category
#  11  Overall.Qual     2877 non-null   category
#  12  Overall.Cond     2877 non-null   category
#  13  Roof.Style       2877 non-null   category
#  14  Mas.Vnr.Type     2877 non-null   category
#  15  Mas.Vnr.Area     2877 non-null   float64
#  16  Exter.Qual       2877 non-null   category
#  17  Exter.Cond       2877 non-null   category
#  18  Foundation       2877 non-null   category
#  19  Bsmt.Qual        2877 non-null   category
#  20  Bsmt.Cond        2877 non-null   category
#  21  Bsmt.Exposure    2877 non-null   category
#  22  BsmtFin.Type.1   2877 non-null   category
#  23  BsmtFin.SF.1     2877 non-null   float64
#  24  BsmtFin.Type.2   2877 non-null   category
#  25  BsmtFin.SF.2     2877 non-null   float64
#  26  Bsmt.Unf.SF      2877 non-null   float64
#  27  Total.Bsmt.SF    2877 non-null   float64
#  28  Heating.QC       2877 non-null   category
#  29  Central.Air      2877 non-null   category
#  30  Electrical       2877 non-null   category
#  31  X1st.Flr.SF      2877 non-null   float64
#  32  X2nd.Flr.SF      2877 non-null   float64
#  33  Low.Qual.Fin.SF  2877 non-null   float64
#  34  Gr.Liv.Area      2877 non-null   float64
#  35  Bsmt.Full.Bath   2877 non-null   float64
#  36  Bsmt.Half.Bath   2877 non-null   float64
#  37  Full.Bath        2877 non-null   float64
#  38  Half.Bath        2877 non-null   float64
#  39  Bedroom.AbvGr    2877 non-null   float64
#  40  Kitchen.AbvGr    2877 non-null   float64
#  41  Kitchen.Qual     2877 non-null   category
#  42  TotRms.AbvGrd    2877 non-null   float64
#  43  Functional       2877 non-null   category
#  44  Fireplaces       2877 non-null   float64
#  45  Garage.Type      2877 non-null   category
#  46  Garage.Finish    2877 non-null   category
#  47  Garage.Cars      2877 non-null   float64
#  48  Garage.Area      2877 non-null   float64
#  49  Paved.Drive      2877 non-null   category
#  50  Wood.Deck.SF     2877 non-null   float64
#  51  Open.Porch.SF    2877 non-null   float64
#  52  Enclosed.Porch   2877 non-null   float64
#  53  X3Ssn.Porch      2877 non-null   float64
#  54  Screen.Porch     2877 non-null   float64
#  55  Pool.Area        2877 non-null   float64
#  56  Fence            2877 non-null   category
#  57  Misc.Val         2877 non-null   float64
#  58  Mo.Sold          2877 non-null   float64
#  59  Yr.Sold          2877 non-null   float64
#  60  Sale.Type        2877 non-null   category
#  61  Sale.Condition   2877 non-null   category
#  62  SalePrice        2877 non-null   float64
#  63  Condition        2877 non-null   category
#  64  HasShed          2877 non-null   bool
#  65  HasAlley         2877 non-null   bool
#  66  Exterior         2877 non-null   category
#  67  Garage.Age       2877 non-null   float64
#  68  Remod.Age        2877 non-null   float64
#  69  House.Age        2877 non-null   float64
# dtypes: bool(2), category(34), float64(34)
# memory usage: 889.4 KB

# %%
model_data = data.copy()

# %% [markdown]
# ## Preparing the data for the model

# %% [markdown]
# Now that we have the data all cleaned, and all the missing values accounted for, lets focus on transforming the data for the model.
#
# Lets remember what a model is.
#
# - A predictive model is a **set** of functions that receive data as input and produce a prediction, that is, an estimate of the target value as output.
# - **Train** a model is to search the set of candidate functions for one that adequately represents the **training dataset**.
# - The adequacy of a candidate function to the training data is usually determined by a **loss function** that measures how well the predictions of the function match the real values of the target within the training dataset. It is common to define a *loss function per data item* (e.g. absolute error, quadratic error, etc) and to construct the *loss function over the dataset* as the *average prediction loss*.
#
# Many models are **parametric models**. In this case, each function of the set of functions that makes the model is constructed from a vector of **parameters** that define the function, forming a **parametric function**. For instance: the linear model constructs prediction values out of a linear combination of the input features, plus a constant. The weights of the linear combination plus the constant are the parameters of the model. The set of functions that can be represented by this model is given by all possible values of the vector of parameters that define the function.
#
# Some models are called **non-parametric models**. These models usually do not have a parametric form (like the linear model). But the terminology is a bit misleading, though: usually these models *do* have parameters, and potentially an open-ended set of them! For instance, consider the "decision tree" model, which is one of the most prominent models of this category. The decision tree may not have a formula for the predicted value, but it does have parameters, many of them: each decision in the tree involves a choice of feature and a threshold level, and those choices must be stored as parameters of the model for use in future predictions.
#
# Each model has specific requirements for the format of the input data. Most of the time, the minimum requirement is that:
#
# - All columns are numeric;
# - There are no missing values.
#
# Some models have extra requirements. For example: the support-vector-machines model requires that the input features have comparable standard deviations - having features that have large discrepancies between features in terms of their order of magnitude (such as a feature in the fractions of unit range and another in the tens of thousands) will result in poor prediction quality.
#
# And some models may not have any special requirement at all. We will study each of those in detail in this course.
#
# Lets start our study with a simple model: the *multivariate linear regression* model. This is a model that presents the minimum requirements listed above. So we need to do a bit of processing on the original features:
#
# - *Numerical features* stay as given;
# - *Categorical features* have to be transformed into numerical features. In order to do so we need to **encode** these features, that is: to transform them into new features that convey the same information, but in a numerical form, and in a way that "makes sense" - we'll see it below.
# - *Ordinal features* can be transformed into numerical features in the same way as the caegorical features, or could be assigned increasing numbers in conformity with the ordered nature of the categories of the feature.

# %% [markdown]
# ## Encoding categorical variables

# %% [markdown]
# Lets identify all categorical variables - both nominal (that is, categoricals without category order) and ordinal.

# %%
categorical_columns = []
ordinal_columns = []
for col in model_data.select_dtypes('category').columns:
    if model_data[col].cat.ordered:
        ordinal_columns.append(col)
    else:
        categorical_columns.append(col)

# %%
ordinal_columns
# Out:
# ['Lot.Shape',
#  'Land.Slope',
#  'Overall.Qual',
#  'Overall.Cond',
#  'Exter.Qual',
#  'Exter.Cond',
#  'Heating.QC',
#  'Electrical',
#  'Kitchen.Qual',
#  'Functional',
#  'Paved.Drive',
#  'Fence']

# %%
categorical_columns
# Out:
# ['MS.SubClass',
#  'MS.Zoning',
#  'Land.Contour',
#  'Lot.Config',
#  'Neighborhood',
#  'Bldg.Type',
#  'House.Style',
#  'Roof.Style',
#  'Mas.Vnr.Type',
#  'Foundation',
#  'Bsmt.Qual',
#  'Bsmt.Cond',
#  'Bsmt.Exposure',
#  'BsmtFin.Type.1',
#  'BsmtFin.Type.2',
#  'Central.Air',
#  'Garage.Type',
#  'Garage.Finish',
#  'Sale.Type',
#  'Sale.Condition',
#  'Condition',
#  'Exterior']

# %% [markdown]
# ### Encoding ordinal variables

# %% [markdown]
# Ordinal variables can be transformed into integer numbers in a straightforward manner: the lowest category is assigned the value "zero", the next category is given the value "one", etc. The `Pandas` library has a function for this task: `factorize()`:

# %%
for col in ordinal_columns:
    codes, _ = pd.factorize(data[col], sort=True)
    model_data[col] = codes

# %% [markdown]
# Lets confirm that the variables are no longer ordinal, but now are integers:

# %%
model_data[ordinal_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2877 entries, 0 to 2929
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Lot.Shape     2877 non-null   int64
#  1   Land.Slope    2877 non-null   int64
#  2   Overall.Qual  2877 non-null   int64
#  3   Overall.Cond  2877 non-null   int64
#  4   Exter.Qual    2877 non-null   int64
#  5   Exter.Cond    2877 non-null   int64
#  6   Heating.QC    2877 non-null   int64
#  7   Electrical    2877 non-null   int64
#  8   Kitchen.Qual  2877 non-null   int64
#  9   Functional    2877 non-null   int64
#  10  Paved.Drive   2877 non-null   int64
#  11  Fence         2877 non-null   int64
# dtypes: int64(12)
# memory usage: 292.2 KB

# %% [markdown]
# Compare the original values with the encoded values:

# %%
data['Lot.Shape'].value_counts()
# Out:
# Lot.Shape
# Reg    1825
# IR1     960
# IR2      76
# IR3      16
# Name: count, dtype: int64

# %%
model_data['Lot.Shape'].value_counts()
# Out:
# Lot.Shape
# 0    1825
# 1     960
# 2      76
# 3      16
# Name: count, dtype: int64

# %% [markdown]
# ### Encoding nominal variables

# %% [markdown]
# With nominal variables there is no notion of order among categories. Therefore, it would be a conceptual mistake to encode them in the same manner as the ordinal variables. For instance, consider the `Exterior` variable:

# %%
model_data['Exterior'].value_counts()
# Out:
# Exterior
# VinylSd    1024
# HdBoard     439
# MetalSd     432
# Wd Sdng     401
# Plywood     218
# CemntBd     126
# BrkFace      86
# WdShing      55
# Stucco       42
# AsbShng      41
# Other        13
# Name: count, dtype: int64

# %% [markdown]
# We cannot assign an order here, lest we end up with equations like `HdBoard` + `Plywood` = `CemntBd`, which are nonsense.
#
# The strategy here to encode `Exterior` is to create several new numerical variables to represent the membership of a given data item to one of the `Exterior` categories. These are called **dummy variables**. Each of these new variables contain only the values "zero" or "one" (i.e. they are binary variables), where $1$ denotes that the data item belongs to the category represented by the variable. Evidently, for a given data item, only one dummy variable has a value of $1$, all remaining are $0$.
#
# There are two types of dummy variable encoding:
#
# - "One-hot" encoding: in this case we create one dummy variable per category. Let's look at the `Exterior` feature as an example. The `Pandas` function `get_dummies()` can do the encoding for us:

# %%
original_data = model_data['Exterior']
encoded_data = pd.get_dummies(original_data)

aux_dataframe = encoded_data
aux_dataframe['Exterior'] = original_data.copy()

aux_dataframe.head().transpose()
# Out:
#                 0        1        2        3        4
# AsbShng     False    False    False    False    False
# BrkFace      True    False    False     True    False
# CemntBd     False    False    False    False    False
# HdBoard     False    False    False    False    False
# MetalSd     False    False    False    False    False
# Plywood     False    False    False    False    False
# Stucco      False    False    False    False    False
# VinylSd     False     True    False    False     True
# Wd Sdng     False    False     True    False    False
# WdShing     False    False    False    False    False
# Other       False    False    False    False    False
# Exterior  BrkFace  VinylSd  Wd Sdng  BrkFace  VinylSd

# %% [markdown]
# Observe that for each value of `Exterior`, only the corresponding dummy is flagged.
#
# One-hot encoding is a popular technique in Machine Learning. Statisticians, however, prefer a slightly different way of dummy encoding which is:
#
# - Choose a category to *not encode* (this is called the *base category*)
# - Generate dummies for the remaining categories. That is:
#     - If the data item belongs to the base category, no dummy receives a value of $1$;
#     - Otherwise, set the corresponding dummy to $1$.
#
# The same `get_dummies()` function of `Pandas` can do this automatically with the `drop_first` argument:

# %%
original_data = model_data['Exterior']
encoded_data = pd.get_dummies(original_data, drop_first=True)

aux_dataframe = encoded_data
aux_dataframe['Exterior'] = original_data.copy()

aux_dataframe.head().transpose()
# Out:
#                 0        1        2        3        4
# BrkFace      True    False    False     True    False
# CemntBd     False    False    False    False    False
# HdBoard     False    False    False    False    False
# MetalSd     False    False    False    False    False
# Plywood     False    False    False    False    False
# Stucco      False    False    False    False    False
# VinylSd     False     True    False    False     True
# Wd Sdng     False    False     True    False    False
# WdShing     False    False    False    False    False
# Other       False    False    False    False    False
# Exterior  BrkFace  VinylSd  Wd Sdng  BrkFace  VinylSd

# %% [markdown]
# Notice that we are now missing the dummy variable for the `AsbShng` category.
#
# Why to encode things this way? If we don't drop one of the dummies, then it will always be the case that the sum of the values of the dummies is $1$ (since each data item must belong to one of the categories). The linear model, particularly very popular with the statisticians, implies the existence of a fictitious feature containing, for all data items, the value $1$. Hence we end up having a set of variables where a linear combination of them (in this case, the sum of the dummies) matches the value at another variable. This has numerical computing implications for the linear model, that we will discuss in class.
#
# Since we want to use the linear model in this notebook, lets encode all categoricals with the `drop_first` alternative.

# %%
model_data = pd.get_dummies(model_data, drop_first=True)

# %% [markdown]
# Now our dataset has a lot more variables!

# %%
model_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2877 entries, 0 to 2929
# Columns: 165 entries, Lot.Frontage to Exterior_Other
# dtypes: bool(119), float64(34), int64(12)
# memory usage: 1.4 MB

# %%
for cat in categorical_columns:
    dummies = []
    for col in model_data.columns:
        if col.startswith(cat + "_"):
            dummies.append(f'"{col}"')
    dummies_str = ', '.join(dummies)
    print(f'From column "{cat}" we made {dummies_str}\n')
# Out:
# From column "MS.SubClass" we made "MS.SubClass_30", "MS.SubClass_50", "MS.SubClass_60", "MS.SubClass_70", "MS.SubClass_80", "MS.SubClass_85", "MS.SubClass_90", "MS.SubClass_120", "MS.SubClass_160", "MS.SubClass_190", "MS.SubClass_Other"
#
# From column "MS.Zoning" we made "MS.Zoning_RH", "MS.Zoning_RL", "MS.Zoning_RM"
#
# From column "Land.Contour" we made "Land.Contour_HLS", "Land.Contour_Low", "Land.Contour_Lvl"
#
# From column "Lot.Config" we made "Lot.Config_CulDSac", "Lot.Config_FR2", "Lot.Config_FR3", "Lot.Config_Inside"
#
# From column "Neighborhood" we made "Neighborhood_BrDale", "Neighborhood_BrkSide", "Neighborhood_ClearCr", "Neighborhood_CollgCr", "Neighborhood_Crawfor", "Neighborhood_Edwards", "Neighborhood_Gilbert", "Neighborhood_IDOTRR", "Neighborhood_MeadowV", "Neighborhood_Mitchel", "Neighborhood_NAmes", "Neighborhood_NPkVill", "Neighborhood_NWAmes", "Neighborhood_NoRidge", "Neighborhood_NridgHt", "Neighborhood_OldTown", "Neighborhood_SWISU", "Neighborhood_Sawyer", "Neighborhood_SawyerW", "Neighborhood_Somerst", "Neighborhood_StoneBr", "Neighborhood_Timber", "Neighborhood_Veenker"
#
# From column "Bldg.Type" we made "Bldg.Type_2fmCon", "Bldg.Type_Duplex", "Bldg.Type_Twnhs", "Bldg.Type_TwnhsE"
#
# From column "House.Style" we made "House.Style_1.5Unf", "House.Style_1Story", "House.Style_2.5Fin", "House.Style_2.5Unf", "House.Style_2Story", "House.Style_SFoyer", "House.Style_SLvl"
#
# From column "Roof.Style" we made "Roof.Style_Hip", "Roof.Style_Other"
#
# From column "Mas.Vnr.Type" we made "Mas.Vnr.Type_Stone", "Mas.Vnr.Type_Other", "Mas.Vnr.Type_None"
#
# From column "Foundation" we made "Foundation_CBlock", "Foundation_PConc", "Foundation_Other"
#
# From column "Bsmt.Qual" we made "Bsmt.Qual_Gd", "Bsmt.Qual_TA", "Bsmt.Qual_Fa", "Bsmt.Qual_NA"
#
# From column "Bsmt.Cond" we made "Bsmt.Cond_TA", "Bsmt.Cond_Fa", "Bsmt.Cond_NA"
#
# From column "Bsmt.Exposure" we made "Bsmt.Exposure_Av", "Bsmt.Exposure_Mn", "Bsmt.Exposure_No", "Bsmt.Exposure_NA"
#
# From column "BsmtFin.Type.1" we made "BsmtFin.Type.1_ALQ", "BsmtFin.Type.1_BLQ", "BsmtFin.Type.1_Rec", "BsmtFin.Type.1_LwQ", "BsmtFin.Type.1_Unf", "BsmtFin.Type.1_NA"
#
# From column "BsmtFin.Type.2" we made "BsmtFin.Type.2_ALQ", "BsmtFin.Type.2_BLQ", "BsmtFin.Type.2_Rec", "BsmtFin.Type.2_LwQ", "BsmtFin.Type.2_Unf", "BsmtFin.Type.2_NA"
#
# From column "Central.Air" we made "Central.Air_Y"
#
# From column "Garage.Type" we made "Garage.Type_Attchd", "Garage.Type_Basment", "Garage.Type_BuiltIn", "Garage.Type_CarPort", "Garage.Type_Detchd", "Garage.Type_NoGarage"
#
# From column "Garage.Finish" we made "Garage.Finish_RFn", "Garage.Finish_Unf", "Garage.Finish_NoGarage"
#
# From column "Sale.Type" we made "Sale.Type_GroupedWD", "Sale.Type_Other"
#
# From column "Sale.Condition" we made "Sale.Condition_AdjLand", "Sale.Condition_Alloca", "Sale.Condition_Family", "Sale.Condition_Normal", "Sale.Condition_Partial"
#
# From column "Condition" we made "Condition_Railroad", "Condition_Roads", "Condition_Positive", "Condition_RoadsAndRailroad"
#
# From column "Exterior" we made "Exterior_BrkFace", "Exterior_CemntBd", "Exterior_HdBoard", "Exterior_MetalSd", "Exterior_Plywood", "Exterior_Stucco", "Exterior_VinylSd", "Exterior_Wd Sdng", "Exterior_WdShing", "Exterior_Other"

# %% [markdown]
# ## Train-test splitting

# %% [markdown]
# The data will now be organized as follows:
#
# - The features form a matrix $X$ of size $m \times n$, where $m$ is the number of data items, and $n$ is the number of features.
# - The target forms a column-matrix $y$ of length $m$.

# %%
X = model_data.drop(columns=['SalePrice']).copy()
y = model_data['SalePrice'].copy()

# %%
X, y
# Out:
# (      Lot.Frontage  Lot.Area  Lot.Shape  Land.Slope  Overall.Qual  \
#  0            141.0   31770.0          1           0             5
#  1             80.0   11622.0          0           0             4
#  2             81.0   14267.0          1           0             5
#  3             93.0   11160.0          0           0             6
#  4             74.0   13830.0          1           0             4
#  ...            ...       ...        ...         ...           ...
#  2925          37.0    7937.0          1           0             5
#  2926          68.0    8885.0          1           1             4
#  2927          62.0   10441.0          0           0             4
#  2928          77.0   10010.0          0           1             4
#  2929          74.0    9627.0          0           1             6
#
#        Overall.Cond  Mas.Vnr.Area  Exter.Qual  Exter.Cond  BsmtFin.SF.1  ...  \
#  0                4         112.0           2           2         639.0  ...
#  1                5           0.0           2           2         468.0  ...
#  2                5         108.0           2           2         923.0  ...
#  3                4           0.0           1           2        1065.0  ...
#  4                4           0.0           2           2         791.0  ...
#  ...            ...           ...         ...         ...           ...  ...
#  2925             5           0.0           2           2         819.0  ...
#  2926             4           0.0           2           2         301.0  ...
#  2927             4           0.0           2           2         337.0  ...
#  2928             4           0.0           2           2        1071.0  ...
#  2929             4          94.0           2           2         758.0  ...
#
#        Exterior_BrkFace  Exterior_CemntBd  Exterior_HdBoard  Exterior_MetalSd  \
#  0                 True             False             False             False
#  1                False             False             False             False
#  2                False             False             False             False
#  3                 True             False             False             False
#  4                False             False             False             False
#  ...                ...               ...               ...               ...
#  2925             False             False              True             False
#  2926             False             False              True             False
#  2927             False             False              True             False
#  2928             False             False              True             False
#  2929             False             False              True             False
#
#        Exterior_Plywood  Exterior_Stucco  Exterior_VinylSd  Exterior_Wd Sdng  \
#  0                False            False             False             False
#  1                False            False              True             False
#  2                False            False             False              True
#  3                False            False             False             False
#  4                False            False              True             False
#  ...                ...              ...               ...               ...
#  2925             False            False             False             False
#  2926             False            False             False             False
#  2927             False            False             False             False
#  2928             False            False             False             False
#  2929             False            False             False             False
#
#        Exterior_WdShing  Exterior_Other
#  0                False           False
#  1                False           False
#  2                False           False
#  3                False           False
#  4                False           False
#  ...                ...             ...
#  2925             False           False
#  2926             False           False
#  2927             False           False
#  2928             False           False
#  2929             False           False
#
#  [2877 rows x 164 columns],
#  0       5.332438
#  1       5.021189
#  2       5.235528
#  3       5.387390
#  4       5.278525
#            ...
#  2925    5.153815
#  2926    5.117271
#  2927    5.120574
#  2928    5.230449
#  2929    5.274158
#  Name: SalePrice, Length: 2877, dtype: float64)

# %% [markdown]
# This is the typical set-up of a machine learning project. Now we want to train our model *and* verify that the model provides good predictions for *unseen* data items. Why the emphasis on "unseen"? Because there is no use for a model that only gives predictions for the items in the data used to train it - we want our models to *generalize*.
#
# The way to assess the model's performance for unseen values is to split the dataset into two subsets: the **training** and **test** datasets.
#
# We have been using a lot of `Pandas` to manipulate our data so far. From now on we will switch to another very popular library for machine learning in Python: `Scikit-Learn`.
#
# The function `train_test_split()` will take as arguments the dataset to be split, the specification of the fraction of the dataset to be reserved for testing, and a random seed value - so that the split will always be the same whenever we run our notebook. This is a customary measure to ensure reproducibility of the notebook.

# %%
from sklearn.model_selection import train_test_split

# %%
RANDOM_SEED = 42  # Any number here, really.

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=RANDOM_SEED,
)

# %%
X.shape, Xtrain.shape, Xtest.shape
# Out:
# ((2877, 164), (2157, 164), (720, 164))

# %%
y.shape, ytrain.shape, ytest.shape
# Out:
# ((2877,), (2157,), (720,))

# %%
#Use Lasso regression to select features
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

sel_ = SelectFromModel(Lasso(alpha=0.005, random_state=RANDOM_SEED))
sel_.fit(Xtrain, ytrain)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=42))

# %%
#Features selected by Lasso
selected_feat = Xtrain.columns[(sel_.get_support())]
len(selected_feat)
# Out:
# 22

# %%
#Filtering features
# Xtrain = Xtrain[selected_feat]
# Xtest = Xtest[selected_feat]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures


numerical_data = Xtrain.select_dtypes("float64").columns


column_transformer = ColumnTransformer(
    transformers=[
        ('numeric', StandardScaler(), numerical_data),
        ('polynomial', PolynomialFeatures(degree=2, include_bias=False), numerical_data),
    ],
    remainder='passthrough',
)

# column_transformer.fit(Xtrain)

# Xtrain_transformed = column_transformer.transform(Xtrain)
# Xtest_transformed = column_transformer.transform(Xtest)

Xtrain_transformed = Xtrain
Xtest_transformed = Xtest

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'alpha': np.logspace(-4, 0, 100),
}

lasso = GridSearchCV(
    Lasso(),
    param_grid=param_grid,
    cv=10,
    n_jobs=-1,
    verbose=2,
)

# %%
lasso.fit(Xtrain_transformed, ytrain)

print(lasso.best_params_)
print(lasso.best_score_)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00010974987654930556; total time=   0.3s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .......................alpha=0.00012045035402587823; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .......................alpha=0.00013219411484660288; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END .........................alpha=0.000145082877849594; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END .......................alpha=0.00015922827933410923; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END ........................alpha=0.0001747528400007683; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.3s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00019179102616724886; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00021049041445120198; total time=   0.3s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END .......................alpha=0.00023101297000831605; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END .......................alpha=0.00025353644939701115; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.1s
# [CV] END ........................alpha=0.0002782559402207126; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.0s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.2s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003053855508833416; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.1s
# [CV] END ........................alpha=0.0003351602650938841; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.1s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.0s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.0s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.0s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.1s
# [CV] END ........................alpha=0.0003678379771828634; total time=   0.1s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0004037017258596554; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.0s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END ........................alpha=0.0004430621457583882; total time=   0.1s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.0s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.0s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.0s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.0s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.1s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.0s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.0s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.0s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.1s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.1s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.0s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.1s
# [CV] END .......................alpha=0.00048626015800653534; total time=   0.1s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.1s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.1s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.0s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.1s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.0s
# [CV] END ........................alpha=0.0005336699231206312; total time=   0.1s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.0s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.0s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.1s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.1s
# [CV] END ........................alpha=0.0005857020818056667; total time=   0.1s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.1s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.1s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.1s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.1s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.0s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.1s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.0s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.0s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.1s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.1s
# [CV] END ........................alpha=0.0006428073117284319; total time=   0.0s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.0s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.0s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.1s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.0s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.0s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.0s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.1s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.0s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.0s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.1s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.0s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.0s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.1s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.0s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.1s
# [CV] END .........................alpha=0.000774263682681127; total time=   0.0s
# [CV] END ........................alpha=0.0007054802310718645; total time=   0.1s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.0s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.1s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.0s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.1s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.0s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.1s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.0s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.0s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.0s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.0s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.0s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.0s
# [CV] END ........................alpha=0.0008497534359086447; total time=   0.0s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.1s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.0s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.1s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.0s
# [CV] END ........................alpha=0.0009326033468832199; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END .........................alpha=0.001023531021899027; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0011233240329780276; total time=   0.1s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.1s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END ........................alpha=0.0012328467394420659; total time=   0.0s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.1s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END ........................alpha=0.0013530477745798076; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END .........................alpha=0.001484968262254465; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END ........................alpha=0.0016297508346206436; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END .........................alpha=0.001788649529057435; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END ........................alpha=0.0019630406500402726; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END ........................alpha=0.0021544346900318843; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END .........................alpha=0.002364489412645407; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END .........................alpha=0.002595024211399737; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.1s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END .........................alpha=0.002848035868435802; total time=   0.0s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.1s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.1s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END .........................alpha=0.003430469286314919; total time=   0.0s
# [CV] END ........................alpha=0.0031257158496882354; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END ........................alpha=0.0037649358067924714; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END ........................alpha=0.0041320124001153384; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.1s
# [CV] END .........................alpha=0.004977023564332114; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END .........................alpha=0.004534878508128582; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.1s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END ........................alpha=0.0054622772176843425; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END .........................alpha=0.005994842503189409; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.006579332246575682; total time=   0.0s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.0s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.0s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.0s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.1s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.0s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.0s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.0s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.0s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.0s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.0s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.0s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.2s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.2s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.2s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.1s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.0s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.0s
# [CV] END .........................alpha=0.007220809018385471; total time=   0.0s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.2s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.2s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.2s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.0s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.0s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.1s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.0s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.2s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.2s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.1s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.0s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.1s
# [CV] END .........................alpha=0.008697490026177835; total time=   0.0s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.2s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.1s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.1s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.2s
# [CV] END .........................alpha=0.007924828983539177; total time=   0.2s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.2s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.1s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.0s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.2s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.0s
# [CV] END .........................alpha=0.009545484566618348; total time=   0.2s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.0s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.2s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.2s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.1s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.2s
# [CV] END .........................alpha=0.010476157527896652; total time=   0.2s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.1s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.1s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.2s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.2s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.2s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.0s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.0s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.2s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.2s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.1s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.3s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.2s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.2s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.2s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.1s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.2s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.2s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.0s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.2s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.1s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.2s
# [CV] END .........................alpha=0.012618568830660211; total time=   0.0s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.2s
# [CV] END .........................alpha=0.011497569953977368; total time=   0.2s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.1s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.1s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.1s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.2s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.0s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.1s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.2s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.0s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.2s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.0s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.1s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.0s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.2s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.2s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.1s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.1s
# [CV] END .........................alpha=0.013848863713938732; total time=   0.2s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.1s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.1s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.1s
# [CV] END .........................alpha=0.015199110829529346; total time=   0.1s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.1s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.1s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.1s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.1s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.0s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.1s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.1s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.0s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.0s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.1s
# [CV] END .........................alpha=0.022051307399030457; total time=   0.0s
# [CV] END .........................alpha=0.022051307399030457; total time=   0.1s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.1s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.2s
# [CV] END .........................alpha=0.018307382802953697; total time=   0.1s
# [CV] END .........................alpha=0.016681005372000592; total time=   0.2s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.1s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.1s
# [CV] END .........................alpha=0.022051307399030457; total time=   0.1s
# [CV] END .........................alpha=0.022051307399030457; total time=   0.1s
# [CV] END .........................alpha=0.026560877829466867; total time=   0.1s
# [CV] END .........................alpha=0.022051307399030457; total time=   0.1s
# [CV] END .........................alpha=0.024201282647943835; total time=   0.1s
# [CV] END .........................alpha=0.024201282647943835; total time=   0.1s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.1s
# [CV] END ..........................alpha=0.02009233002565048; total time=   0.1s
# [CV] END .........................alpha=0.024201282647943835; total time=   0.1s
# [CV] END .........................alpha=0.022051307399030457; total time=   0.1s[CV] END .........................alpha=0.024201282647943835; total time=   0.0s
#
# [CV] END .........................alpha=0.026560877829466867; total time=   0.1s
# ...
# [CV] END ..........................alpha=0.15556761439304723; total time=   0.2s
# [CV] END ...........................alpha=0.1707352647470692; total time=   0.2s
# [CV] END ..........................alpha=0.15556761439304723; total time=   0.2s
# [CV] END ..........................alpha=0.15556761439304723; total time=   0.2s
# [CV] END ...........................alpha=0.1707352647470692; total time=   0.2s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.2s
# [CV] END ...........................alpha=0.1707352647470692; total time=   0.2s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.2s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.2s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.1s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.2s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.2s
# [CV] END ...........................alpha=0.1707352647470692; total time=   0.2s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.2s
# [CV] END ...........................alpha=0.1707352647470692; total time=   0.2s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.1s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.2s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.2s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.2s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.2s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.1s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.1s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.1s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.1s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.2s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.2s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.2s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.2s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.2s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.2s
# [CV] END ...........................alpha=0.1873817422860385; total time=   0.2s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.2s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.1s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.2s
# [CV] END ..........................alpha=0.20565123083486536; total time=   0.1s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.1s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.1s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.1s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.2s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.1s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.1s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.1s
# [CV] END ..........................alpha=0.22570197196339215; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ..........................alpha=0.24770763559917114; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ...........................alpha=0.2718588242732943; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ............................alpha=0.298364724028334; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ...........................alpha=0.3274549162877732; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ...........................alpha=0.3593813663804629; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ............................alpha=0.394420605943766; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ..........................alpha=0.43287612810830617; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.0s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.1s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.1s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.0s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ...........................alpha=0.4750810162102798; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.1s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ............................alpha=0.521400828799969; total time=   0.1s
# [CV] END ............................alpha=0.572236765935022; total time=   0.0s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.0s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.1s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.1s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.0s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.0s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.1s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.1s
# [CV] END ............................alpha=0.572236765935022; total time=   0.1s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.1s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.1s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.1s[CV] END ...........................alpha=0.6280291441834259; total time=   0.1s
#
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.0s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.6280291441834259; total time=   0.1s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.0s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.0s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.0s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.7564633275546291; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.1s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.0s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.1s
# [CV] END ...........................alpha=0.6892612104349702; total time=   0.1s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.0s
# [CV] END ...........................alpha=0.8302175681319752; total time=   0.0s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.1s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.0s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.0s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.1s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.0s
# [CV] END ...........................alpha=0.9111627561154896; total time=   0.1s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.1s
# {'alpha': 0.0001}
# 0.9030912466049736

# %%
from sklearn.linear_model import LinearRegression

linear = GridSearchCV(
    LinearRegression(),
    param_grid={},
    cv=10,
    n_jobs=-1,
    verbose=2,
)

linear.fit(Xtrain_transformed, ytrain)

print(linear.best_score_)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.0s
# 0.9014453623982982

# %%
# import random forest regressor
from sklearn.ensemble import RandomForestRegressor

# create a dictionary of parameters
param_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [2, 3, 4, 5, 6, 7, 8],
    'max_features': ['auto', 'sqrt', 'log2'],
    'min_samples_split': [2, 3, 4, 5, 6, 7, 8],
    'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8],
}

# create Random Forest model
rf_model = RandomForestRegressor(random_state=RANDOM_SEED)

# set up grid search meta-estimator
rf = GridSearchCV(
    rf_model,
    param_grid,
    cv=5,
    n_jobs=-1,
    verbose=2,
)

# train the grid search meta-estimator to find the best model
rf.fit(Xtrain_transformed, ytrain)

# print winning set of hyperparameters
print(rf.best_params_)

# print accuracy score
print(rf.best_score_)
# Out:
# Fitting 5 folds for each of 5880 candidates, totalling 29400 fits
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s[CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
#
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100; total time=   0.0s[CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=300; total time=   0.0s
#
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=400; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   0.0s
# [CV] END max_depth=2, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=500; total time=   0.0s
# ...
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=400; total time=   1.0s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=500; total time=   1.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=500; total time=   1.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=500; total time=   1.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=500; total time=   1.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=4, n_estimators=500; total time=   1.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   1.1s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   1.0s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   1.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=400; total time=   1.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=500; total time=   1.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=500; total time=   2.0s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=200; total time=   0.7s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=200; total time=   0.7s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=200; total time=   0.7s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=300; total time=   0.8s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   1.1s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=500; total time=   1.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=100; total time=   0.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=100; total time=   0.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=500; total time=   1.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=500; total time=   1.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=500; total time=   1.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=6, n_estimators=500; total time=   1.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=300; total time=   0.8s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=300; total time=   0.8s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=300; total time=   0.8s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=400; total time=   1.1s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=400; total time=   1.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=400; total time=   1.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=400; total time=   1.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=500; total time=   1.4s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=500; total time=   1.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=500; total time=   1.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=500; total time=   1.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   0.5s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=500; total time=   1.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=300; total time=   0.8s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=300; total time=   0.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=400; total time=   1.1s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=400; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=500; total time=   1.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=500; total time=   1.2s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=500; total time=   1.3s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=8, min_samples_split=8, n_estimators=500; total time=   1.1s
# /Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 9800 fits failed out of a total of 29400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5359 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 4441 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/enriccogemha/Developer/HousePriceRegressor/venv/lib/python3.9/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan ... 0.82764643 0.82775376 0.82845996]
#   warnings.warn(
# {'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.8717787019236767

# %%
y_pred_linear = linear.predict(Xtest_transformed)

# %%
y_pred_lasso = lasso.predict(Xtest_transformed)

# %%
y_pred_rf = rf.predict(Xtest_transformed)

# %%
from sklearn.metrics import mean_squared_error

RMSE_lasso = np.sqrt(mean_squared_error(ytest, y_pred_lasso))
RMSE_lasso
# Out:
# 0.06234934453643266

# %%
RMSE_linear = np.sqrt(mean_squared_error(ytest, y_pred_linear))
RMSE_linear
# Out:
# 0.061127758761017816

# %%
RMSE_rf = np.sqrt(mean_squared_error(ytest, y_pred_rf))
RMSE_rf
# Out:
# 0.0671349400641507

# %%
error_percent = 100 * (10**RMSE_lasso - 1)
print(f'Average error for Lasso is {error_percent:.2f}%')
# Out:
# Average error for Lasso is 15.44%

# %%
error_percent = 100 * (10**RMSE_linear - 1)
print(f'Average error for Linear is {error_percent:.2f}%')
# Out:
# Average error for Linear is 15.11%

# %%
error_percent = 100 * (10**RMSE_rf - 1)
print(f'Average error for RandomForest is {error_percent:.2f}%')
# Out:
# Average error for RandomForest is 16.72%
